# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
cv2.__version__
# Out:
# '4.6.0'

# %%
# %matplotlib inline

# %%
iname = "lena.png"
img = cv2.imread(iname)
img
# Out:
# [ WARN:0@0.903] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('lena.png'): can't open/read file: check file path/integrity

# %%
img.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 img.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
img.size
# Out:
# 786432

# %%
# cv2.imshow("image", img)

# %%
img_lena = mpimg.imread('lena.jpg')
imgplot = plt.imshow(img_lena)
plt.show()

# %%
plt.imshow(img_lena[:,:,::-1])

# %%
img_lena[0, 0]
# Out:
# array([227, 138, 123], dtype=uint8)

# %%
crop = img_lena[100:300, 100:300]
plt.imshow(crop[:,:,::-1])

# %%
copy = img_lena.copy()
copy[100:300, 100:300] = [255, 0, 0]
plt.imshow(copy[:,:,::-1])

# %%
h, w = img_lena[:2]
resized = cv2.resize(img_lena, (200, 200))
plt.imshow(resized[:,:,::-1])

# %%
cv2.imwrite("test.jpg", resized)
# Out:
# True
